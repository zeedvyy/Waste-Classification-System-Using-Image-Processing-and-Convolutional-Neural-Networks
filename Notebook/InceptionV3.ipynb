# %% [markdown]
# ### Import Library
# - Tahap pertama adalah import seluruh library yang dibutuhkan

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import os
import time
from collections import Counter
from google.colab import drive
import cv2
import matplotlib.pyplot as plt
import os
import random
from glob import glob
import tensorflow as tf
import cv2
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
import keras
import keras._tf_keras.keras.backend as K
import os
import time
from google.colab import drive
from keras._tf_keras.keras.models import Model
from keras._tf_keras.keras.layers import Input, Dense, Conv2D
from keras._tf_keras.keras.layers import Flatten, MaxPool2D, AvgPool2D
from keras._tf_keras.keras.layers import Concatenate, Dropout
from keras._tf_keras.keras.models import load_model

# %% [markdown]
# ### Mount Google Drive
# Untuk mengakses dataset yang disimpan di Google Drive.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Menyalin Dataset ke Workspace
# Menyalin dataset dari Google Drive ke direktori lokal Colab agar proses training lebih cepat.

# %%
# !cp -r /content/drive/MyDrive/TA/Dataset\ Final /content/dataset_final

# %% [markdown]
# ### Memuat Dataset sebagai TensorFlow Dataset dan  Menghitung Jumlah Gambar per Kelas
#
# - Menggunakan image_dataset_from_directory untuk memuat dataset terstruktur dalam folder (setiap subfolder dianggap sebagai label/kategori).
#
# - Menggunakan Counter untuk mengetahui distribusi gambar dalam tiap kelas.

# %%
data_dir = '/content/dataset_final'  # Path direktori dataset

data = tf.keras.utils.image_dataset_from_directory(
    data_dir,                        # Path folder dataset
    image_size=(224, 224),          # Ukuran gambar di-resize jadi 224x224 piksel
    batch_size=8,                   # Jumlah gambar per batch
    shuffle=True                    # Gambar diacak saat dimuat
)

class_names = data.class_names      # Menyimpan label kelas yang ditemukan
print("Class names:", class_names)  # Menampilkan nama kelas

label_counts = Counter()  # Inisialisasi penghitung jumlah label

for images, labels in data:
    for label in labels.numpy():
        class_name = class_names[label]  # Konversi label numerik ke nama kelas
        label_counts[class_name] += 1    # Tambah jumlah gambar per kelas

# Cetak jumlah gambar tiap kelas
print("\nJumlah gambar per kelas:")
total = 0
for class_name in class_names:
    count = label_counts[class_name]
    print(f"{class_name}: {count}")
    total += count
print(f"\nTotal semua gambar: {total}")
# Out:
# Found 17600 files belonging to 4 classes.
# Class names: ['Kaca', 'Kardus', 'Logam', 'Plastik']
#
# Jumlah gambar per kelas:
# Kaca: 4400
# Kardus: 4400
# Logam: 4400
# Plastik: 4400
#
# Total semua gambar: 17600

# %% [markdown]
# ### Menampilkan Sampel Gambar dari Setiap Kelas
#
# Untuk memverifikasi isi dan kualitas dataset secara visual.

# %%
plt.figure(figsize=(14, 6))  # Ukuran kanvas gambar 14x6 inci

for i, class_name in enumerate(class_names):  # Loop tiap kelas
    class_folder = os.path.join(data_dir, class_name)  # Path folder tiap kelas
    img_files = glob(os.path.join(class_folder, '*.jpg')) + \
                glob(os.path.join(class_folder, '*.jpeg')) + \
                glob(os.path.join(class_folder, '*.png'))  # Ambil semua file gambar

    if not img_files:
        continue

    img_path = random.choice(img_files)  # Pilih satu gambar secara acak
    img = cv2.imread(img_path)           # Baca gambar dengan OpenCV (format BGR)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Konversi ke RGB

    plt.subplot(1, len(class_names), i + 1)  # Buat subplot
    plt.imshow(img)
    plt.title(class_name)  # Judul = nama kelas
    plt.xticks([0, img.shape[1]//2, img.shape[1]-1], labels=[0, img.shape[1]//2, img.shape[1]], color='black')
    plt.yticks([0, img.shape[0]//2, img.shape[0]-1], labels=[0, img.shape[0]//2, img.shape[0]], color='black')
    plt.grid(visible=True, color='black', linestyle='--', linewidth=0.5)  # Tampilkan grid
    plt.gca().spines['top'].set_color('black')   # Warna garis tepi
    plt.gca().spines['bottom'].set_color('black')
    plt.gca().spines['left'].set_color('black')
    plt.gca().spines['right'].set_color('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalisasi Gambar (Rescaling 0-1)
# Mengubah nilai piksel dari rentang 0-255 ke 0-1 agar model dapat memproses lebih stabil.

# %%
for images, labels in data.take(1):  # Ambil satu batch
    print(f"Original pixel range: min={tf.reduce_min(images).numpy()}, max={tf.reduce_max(images).numpy()}")
    original_images = images.numpy().astype("uint8")  # Konversi ke uint8

# Fungsi normalisasi
def process_images(images, labels):  # Fungsi normalisasi
    images = tf.cast(images, tf.float32) / 255.0  # Bagi nilai piksel dengan 255
    return images, labels

data = data.map(process_images)  # Terapkan normalisasi ke semua batch

for images, labels in data.take(1):
    print(f"Normalized pixel range: min={tf.reduce_min(images).numpy()}, max={tf.reduce_max(images).numpy()}")

# Tampilkan ukuran gambar
print(f"Image shape: {images[0].shape}")
# Out:
# Original pixel range: min=0.0, max=255.0
# Normalized pixel range: min=0.0, max=1.0
# Image shape: (224, 224, 3)

# %% [markdown]
# ### Membagi Dataset (Train, Validation, Test)
# Dataset dibagi menjadi 80% training, 10% validation, dan 10% test.
#
# - Train, digunakan untuk melatih model agar mengenali pola dalam data
# - Validation, digunakan untuk mengevaluasi performa model selama pelatihan
# - Test, digunakan untuk menguji model setelah pelatihan

# %%
total_batches = tf.data.experimental.cardinality(data).numpy()  # Total batch
train_size = int(0.8 * total_batches)  # 80% untuk pelatihan
val_size = int(0.1 * total_batches)    # 10% untuk validasi

train_data = data.take(train_size)
val_test_data = data.skip(train_size)
val_data = val_test_data.take(val_size)
test_data = val_test_data.skip(val_size)

# %% [markdown]
# ### Optimisasi Pipeline Dataset
# Menggunakan shuffle() dan prefetch() untuk efisiensi pelatihan.

# %%
train_data = train_data.shuffle(100).prefetch(1)  # Acak & prefetch batch untuk training
val_data = val_data.prefetch(1)                   # Prefetch batch validasi
test_data = test_data.prefetch(1)                 # Prefetch batch uji

# %% [markdown]
# ### Load Model Pre-trained InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras import layers, models

# Load base model tanpa top layer (pretrained on ImageNet)
base_model = InceptionV3(input_shape=(224, 224, 3),  # Ukuran input sesuai dengan dataset kita
                         include_top=False,          # Tidak menyertakan layer klasifikasi bawaan
                         weights='imagenet')         # Gunakan bobot hasil pretraining dari ImageNet

base_model.trainable = False  # Membekukan layer dari base model agar tidak dilatih ulang

# Tambahkan classifier di atas base model
model = models.Sequential([               # Membuat model Sequential (berlapis berturut-turut)
    base_model,                           # Gunakan InceptionV3 sebagai feature extractor
    layers.GlobalAveragePooling2D(),      # Meratakan feature map menjadi vektor
    layers.Dense(128, activation='relu'), # Layer fully connected dengan 128 neuron
    layers.Dropout(0.3),                  # Dropout untuk mencegah overfitting
    layers.Dense(len(class_names), activation='softmax')  # Layer output untuk klasifikasi (jumlah kelas = len(class_names))
])

model.compile(
    optimizer='adam',                          # Optimizer Adam (adaptif dan cepat)
    loss='sparse_categorical_crossentropy',    # Loss function untuk klasifikasi multi-kelas (dengan label numerik)
    metrics=['accuracy']                       # Metode evaluasi selama training
)

model.summary()  # Tampilkan arsitektur dan jumlah parameter model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,065,572 (84.17 MB)
#  Trainable params: 262,788 (1.00 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %% [markdown]
# ### Menambahkan Callbacks
# - EarlyStopping: Menghentikan pelatihan jika validasi tidak membaik.
#
# - ReduceLROnPlateau: Mengurangi learning rate jika model stagnan.

# %%
# Callbacks
from tensorflow.keras import layers, models, callbacks
early_stop = EarlyStopping(patience=5, restore_best_weights=True)  # Stop jika val loss tak membaik 5 epoch
reduce_lr = ReduceLROnPlateau(patience=3, factor=0.5, verbose=1)   # Kurangi LR jika stagnan 3 epoch

# %% [markdown]
# ### Melatih Model
# Melatih model dan mengukur waktu pelatihan.

# %%
import time
start_time = time.time() # Mulai hitung waktu

# Training
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=10,
    callbacks=[early_stop, reduce_lr]
)

end_time = time.time() # Catat waktu selesai
elapsed_time = end_time - start_time # Hitung total waktu pelatihan

print(f"Training time: {elapsed_time:.2f} seconds ({elapsed_time/60:.2f} minutes)")
# Out:
# Epoch 1/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 76s 33ms/step - accuracy: 0.7538 - loss: 0.6578 - val_accuracy: 0.8801 - val_loss: 0.3263 - learning_rate: 0.0010
# Epoch 2/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 53s 30ms/step - accuracy: 0.8698 - loss: 0.3521 - val_accuracy: 0.9045 - val_loss: 0.2613 - learning_rate: 0.0010
# Epoch 3/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 53s 30ms/step - accuracy: 0.8922 - loss: 0.2846 - val_accuracy: 0.9159 - val_loss: 0.2314 - learning_rate: 0.0010
# Epoch 4/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 84s 31ms/step - accuracy: 0.9082 - loss: 0.2454 - val_accuracy: 0.9108 - val_loss: 0.2549 - learning_rate: 0.0010
# Epoch 5/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 54s 31ms/step - accuracy: 0.9180 - loss: 0.2273 - val_accuracy: 0.9290 - val_loss: 0.2096 - learning_rate: 0.0010
# Epoch 6/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 54s 30ms/step - accuracy: 0.9189 - loss: 0.2096 - val_accuracy: 0.9256 - val_loss: 0.2353 - learning_rate: 0.0010
# Epoch 7/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 53s 30ms/step - accuracy: 0.9332 - loss: 0.1817 - val_accuracy: 0.9267 - val_loss: 0.2150 - learning_rate: 0.0010
# Epoch 8/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 53s 30ms/step - accuracy: 0.9428 - loss: 0.1514 - val_accuracy: 0.9335 - val_loss: 0.1986 - learning_rate: 0.0010
# Epoch 9/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 54s 30ms/step - accuracy: 0.9394 - loss: 0.1520 - val_accuracy: 0.9415 - val_loss: 0.2039 - learning_rate: 0.0010
# Epoch 10/10
# 1760/1760 ━━━━━━━━━━━━━━━━━━━━ 82s 30ms/step - accuracy: 0.9447 - loss: 0.1408 - val_accuracy: 0.9455 - val_loss: 0.1793 - learning_rate: 0.0010
# Training time: 615.71 seconds (10.26 minutes)

# %% [markdown]
# ###  Visualisasi Akurasi dan Loss
# Grafik ini menunjukkan perkembangan kinerja model selama pelatihan.

# %%
epochs_range = range(1, len(history.history['accuracy']) + 1) # Range sesuai jumlah epoch

plt.figure(figsize=(12, 5)) # Ukuran kanvas
plt.subplot(1, 2, 1)
plt.plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, history.history['loss'], label='Training Loss')
plt.plot(epochs_range, history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi Model dengan Confusion Matrix dan Classification Report
# Mengetahui presisi, recall, dan f1-score dari model pada data uji.

# %%
y_true = [] # Label asli
y_pred = [] # Hasil prediksi

for images, labels in test_data:
    preds = model.predict(images)
    y_true.extend(labels.numpy()) # Simpan label asli
    y_pred.extend(np.argmax(preds, axis=1)) # Ambil prediksi label dengan nilai tertinggi
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step

# %% [markdown]
# ### Prediksi dan Visualisasi pada Sampel Data Uji
# Menampilkan 8 sampel gambar dari data uji beserta label asli dan hasil prediksi.

# %%
print("=== Classification Report ===")
print(classification_report(y_true, y_pred, target_names=class_names))

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
plt.figure(figsize=(10, 8))
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#         Kaca       0.93      0.91      0.92       393
#       Kardus       0.95      0.98      0.96       464
#        Logam       0.93      0.92      0.92       453
#      Plastik       0.93      0.91      0.92       450
#
#     accuracy                           0.93      1760
#    macro avg       0.93      0.93      0.93      1760
# weighted avg       0.93      0.93      0.93      1760

# %%
def test_and_visualize(model, test_data, class_names):
    for images, labels in test_data.take(1):  # Ambil 1 batch dari test set
        preds = model.predict(images)
        pred_labels = np.argmax(preds, axis=1)  # Ambil prediksi label
        acc = np.mean(pred_labels == labels.numpy()) * 100  # Hitung akurasi

        plt.figure(figsize=(15, 4))
        for i in range(min(8, len(images))):  # Maksimum 8 gambar ditampilkan
            plt.subplot(2, 4, i+1)
            plt.imshow(images[i].numpy())
            plt.title(f"True: {class_names[labels[i]]}\nPred: {class_names[pred_labels[i]]}")
            plt.axis("off")
        plt.suptitle(f"Test Sample Predictions (Accuracy: {acc:.2f}%)")
        plt.tight_layout()
        plt.show()
        break

# Panggil fungsi
test_and_visualize(model, test_data, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
